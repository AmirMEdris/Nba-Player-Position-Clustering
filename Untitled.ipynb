# %%
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from statsmodels.api import OLS
import pandas as pd
import numpy
import matplotlib.pyplot as plt
#turning the player data csv into pandas dataframe
df = pd.read_csv("2020teamstats.csv")
df = df.drop(labels = 'Rk',axis = 1)
df = df.drop(labels = 'Team',axis = 1)

df
# Out:
#      G     MP    FG   FGA    FG%    3P   3PA    3P%    2P   2PA  ...    FT%  \
# 0   75  242.3  41.7  90.3  0.461  15.1  41.3  0.367  26.5  49.0  ...  0.779
# 1   73  241.0  43.3  90.9  0.476  13.8  38.9  0.355  29.5  52.0  ...  0.742
# 2   74  241.0  42.2  91.2  0.463  12.9  34.1  0.377  29.3  57.1  ...  0.804
# 3   72  241.4  40.8  90.4  0.451  15.6  45.3  0.345  25.1  45.2  ...  0.791
# 4   72  241.4  41.6  89.2  0.466  12.4  33.5  0.371  29.1  55.8  ...  0.791
# 5   72  242.1  42.6  91.6  0.465  13.6  36.9  0.370  28.9  54.8  ...  0.729
# 6   73  241.0  41.2  88.1  0.468  11.4  31.8  0.358  29.8  56.3  ...  0.834
# 7   72  241.0  41.5  90.9  0.457  12.0  32.6  0.368  29.5  58.3  ...  0.788
# 8   73  240.7  42.5  90.9  0.468  10.9  31.5  0.347  31.6  59.4  ...  0.763
# 9   72  242.1  41.3  89.6  0.461  12.6  34.5  0.364  28.7  55.0  ...  0.801
# 10  73  243.1  39.5  84.4  0.468  13.4  35.4  0.379  26.0  49.0  ...  0.783
# ...

# %%
results = OLS('PTS~REB',df).fit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-c8944210d004> in <module>
# ----> 1 results = OLS('PTS~REB',df).fit()
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     857                  **kwargs):
#     858         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 859                                   hasconst=hasconst, **kwargs)
#     860         if "weights" in self._init_keys:
#     861             self._init_keys.remove("weights")
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     700             weights = weights.squeeze()
#     701         super(WLS, self).__init__(endog, exog, missing=missing,
# ...

# %%
df.shape
# Out:
# (31, 23)

# %%
# !pip install statsmodels
